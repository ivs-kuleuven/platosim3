# %% [markdown]
# # Use Case Example: Photometry

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (11, 10)

# %% [markdown]
# ## Where's my stuff? (For this notebook only)

# %%
import os
baseDir    = os.getenv("PLATO_PROJECT_HOME")
currentDir = os.getcwd()

import sys
sys.path.append(baseDir + "/python")

# %% [markdown]
# ## Import the relevant modules

# %%
from numpy import *
from scipy import optimize
from scipy.stats import binned_statistic
import matplotlib.cm as cm
import h5py
from simfile import SimFile
from simulation import Simulation
import referenceFrames as ref
import platophot as phot
import transits
import noise
from imp import reload
reload(phot)
# Out:
# <module 'platophot' from '/Users/sara/work/Instrumentation/Plato/softwareDevelopment/Platosim3/python/platophot.py'>

# %% [markdown]
# ## Make a proper input yaml file

# %% [markdown]
# I'm only showing some relevant fields of the inputfgs.yaml file. We want to simulate a little more than 1 week of continuous observations with a nominal camera.

# %% [markdown]
# ## General:
#
#     ProjectLocation:             ENV['PLATO_PROJECT_HOME']
#
# ObservingParameters:
#
#     NumExposures:                !000
#     ExposureTime:                21
#     RApointing:                  180
#     DecPointing:                 -70
#     StarCatalogFile:             inputfiles/starcatalog.txt
#
# Sky:
#
#     SkyBackground:               -1    # Stellar + zodiacal background level. Set negative to compute. [phot/pix/s]
#     IncludeVariableSources:      no    # Include time series of variable stars or not
#     VariableSourceList:          inputfiles/varsource.txt  # Ascii file: star ID, path of time series file
#     IncludeCosmicsInSubField:        yes             # Whether or not to include cosmics in the subfield on the CCD
#     IncludeCosmicsInSmearingMap:     yes             # Whether or not to include cosmics in the overscan map
#     IncludeCosmicsInBiasMap:         yes             # Whether or not to include cosmics in the prescan map
#     Cosmics:
#       CosmicHitRate:             10              # Cosmic hit rate [events / cm^2 / s]
#       TrailLength:               [0, 15]         # Intervalof the length of the cosmic trails [pixels]
#       Intensity:                 [2000, 40000]   # Interval of the total number of e- in a cosmic hit [e-]
#
# Platform:
#
#     SolarPanelOrientation:       0
#     UseJitter:                   no
#
# Telescope:
#
#     AzimuthAngle:                0.0
#     TiltAngle:                   0.0
#     UseDrift:                    no
#
# PSF:
#
#     Model:                       MappedFromFile
#     MappedFromFile:
#       Filename:                  inputfiles/psf.hdf5
#       DistanceToOA:              -1
#       RotationAngle:             -1
#       NumberOfPixels:            8
#       ChargeDiffusionStrength:   0.2     # Charge diffusion strength (width of the Gaussian diffusion kernel) [pixels]
#       IncludeChargeDiffusion:    yes     # Include charge diffusion [yes or no]
#
# FEE:
#
#     NominalOperatingTemp:            210.15          # Nominal operating temperature of the FEE [K]
#     ReadoutNoise:                    32.0            # Readout noise for the FEE [e-/pixel] (same for both ADCs)
#     Gain:
#         RefValueLeft:                0.0222          # [ADU/microV]
#         RefValueRight:               0.0222          # [ADU/microV]
#         Stability:                   -300.0e-6       # [ppm/K] = [ADU/microV/K]
#         AllowedDifference:           0.0             # Difference in gain between both ADCs [%]
#     ElectronicOffset:
#         RefValue:                    1000            # Reference value for the electronic offset [ADU/pixel]
#         Stability:                   1               # Offset stability [ADU/pixel/K]
#
# CCD:
#
#     IncludeFlatfield:            no
#     IncludeDarkSignal:           yes
#     IncludeBFE:                  yes
#     IncludePhotonNoise:          yes
#     IncludeReadoutNoise:         yes
#     IncludeCTIeffects:           no
#     IncludeOpenShutterSmearing:  no
#     IncludeAberrationCorrection: no
#     IncludeFieldDistortion:      yes
#     IncludeNaturalVignetting:    no
#     IncludeMechanicalVignetting: no
#     IncludePolarizaion:          no
#     IncludeParticulateContamination:   no
#     IncludeMolecularContamination:     no
#     IncludeConvolution:          yes
#     IncludeFullWellSaturation:   yes
#     IncludeDigitalSaturation:    yes
#     WriteSubPixelImagesToHDF5:   no
#
#
# SubField:
#
#     NumColumns:                  150
#     NumRows:                     150
#     SubPixels:                   32
#
#
# ## Run PlatoSim

# %%
simulation = Simulation("photometrySimulation", "inputphot.yaml")
simulation["ObservingParameters/NumExposures"] = 1000
simulation.outputDir = currentDir
myRun = simulation.run(removeOutputFile = True)
print("Done")
# Out:
# Done

# %%
# %ls -lh PhotometrySimulation.hdf5
# Out:
# -rw-r--r--  1 sara  sara   185M Sep 18 14:59 PhotometrySimulation.hdf5

# %% [markdown]
# In principle, you can continue from simFile and continue exploiting its contents. In this example, we will split up the post-processing for the sake of clarity.

# %% [markdown]
# ## Show an example subfield

# %%
sim = SimFile("photometrySimulation.hdf5")

# %%
image = sim.getImage(0)

# %%
plt.pcolormesh(image, cmap=cm.jet)

# %% [markdown]
# This field contains more than 1700 stars that were tracked!

# %% [markdown]
# ## Plot the positions of stars brighter than V=13 on top

# %% [markdown]
# Find out which stars bright

# %%
allStarIDs, RA, dec, Vmag, xFPmm, yFPmm, rowPix, colPix = sim.getStarCatalog()
brightStarIDs = allStarIDs[Vmag < 13.0]
print("Number of bright stars: {0}".format(len(brightStarIDs)))
# Out:
# Number of bright stars: 392

# %% [markdown]
# Get all starIDs that are on image nr. 0. Note that these IDs are not necessarily the same as 'allStarIDs'. The latter contains all stars that have been detected, even if only in a few images because the star jittered in the subfield.

# %%
starIDsInImage0, row, col, Xmm, Ymm, flux = sim.getStarCoordinates(0)

# %% [markdown]
# Get the array indices of the bright stars in the 'starIDsInImage0' array. This requires a numpy trick.

# %%
brightStarIndices = arange(len(starIDsInImage0))[in1d(starIDsInImage0, brightStarIDs)]

# %% [markdown]
# Now we can extract the row and column values of the bright stars:

# %%
rowBrightStars = row[brightStarIndices]
colBrightStars = col[brightStarIndices]

# %% [markdown]
# Over-plot these row and column coordinates

# %%
plt.pcolormesh(image, cmap=cm.jet)
plt.scatter(floor(colBrightStars)+0.5, floor(rowBrightStars)+0.5, marker='x', c='lightgreen')
plt.xlim(0,100)
plt.ylim(0,100)
# Out:
# (0, 100)

# %% [markdown]
# ## Weighted photometry

# %% [markdown]
# We assume that each pixel value $f_{ij}$ is composed of a signal $s_{ij}$, a background $b_{ij}$, and noise $\epsilon_{ij}$:

# %% [markdown]
# $$ f_{ij} = s_{ij} + b_{ij} + \varepsilon_{ij}$$

# %% [markdown]
# The background $b_{ij}$ is assumed to be known (in practice: read from the HDF5 file), and subtracted first. The total flux of a star is then computed using a weighted sum:

# %% [markdown]
# $$ F \equiv \sum\limits_{ij} \alpha \ w_{ij} (f_{ij} - b_{ij}) $$

# %% [markdown]
# where the weights are exponentially decaying:

# %% [markdown]
# $$w_{ij} = \exp\left(-\frac{(i-i_0)^2 + (j-j_0)^2}{2\sigma^2_{psf}}\right)$$

# %% [markdown]
# The exact (fractional) pixel coordinates $(i_0, j_0)$ of the star will be known using the Gaia catalog. For now, they are assumed to be known (i.e. read from the HDF5 file) as well.

# %% [markdown]
# ## Figure out the width of the PSF

# %%
outputFile = h5py.File("photometrySimulation.hdf5")

# %%
psf = array(outputFile["/PSF/rebinnedPSFsubPixel"])
NsubPixels = outputFile["/InputParameters/SubField"].attrs["SubPixels"]
Npixels = int(psf.shape[0]/NsubPixels)
print("PSF consists of {0}x{0} pixels, with each pixel made up of {1}x{1} subpixels".format(Npixels, NsubPixels))
# Out:
# PSF consists of 8x8 pixels, with each pixel made up of 32x32 subpixels

# %% [markdown]
# Plot the PSF to see what we're dealing with.

# %%
plt.pcolormesh(psf, cmap=cm.nipy_spectral, vmax=0.01)                         # 'vmax' to get a prettier image
plt.grid(True, which='major', axis='both', linestyle='-', color='w')     # To get a 'pixel-grid' on top of it.
plt.xticks(arange(0, psf.shape[0], NsubPixels))
plt.yticks(arange(0, psf.shape[1], NsubPixels))
plt.xlim(0, psf.shape[0])
plt.ylim(0, psf.shape[1])
# Out:
# (0, 256)

# %%
sigmaPSF = phot.computePSFsigma(psf, NsubPixels, 500)
print("Standard deviation of the PSF (assuming symmetry): {0}".format(sigmaPSF))
# Out:
# Standard deviation of the PSF (assuming symmetry): 0.4115890699471987

# %% [markdown]
# The following function extracts the flux of all stars in every image in the HDF5 simulation output file, and writes the results to a second HDF5 file. Depending on the number of exposures, this can take a while.

# %%
print(outputFile["Flatfield"])
# Out:
# <HDF5 group "/Flatfield" (2 members)>

# %%
reload(phot)
print("Start")
phot.photometry("photometrySimulation.hdf5", "photometryOutput.hdf5",starIDsInImage0, maxNexposures=1000)
print("Done")
# Out:
# Start
# 0 1000
# Looping over all images in HDF5 file.
# Image # 0
#     Subtracted bias level of 999.72 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 1
#     Subtracted bias level of 999.4133333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 2
#     Subtracted bias level of 999.6733333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 3
#     Subtracted bias level of 999.68 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 4
#     Subtracted bias level of 999.3733333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 5
#     Subtracted bias level of 999.5866666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 6
#     Subtracted bias level of 999.84 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 7
#     Subtracted bias level of 999.7866666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 8
#     Subtracted bias level of 999.5333333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 9
#     Subtracted bias level of 999.3466666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 10
#     Subtracted bias level of 999.4133333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 11
#     Subtracted bias level of 999.5066666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 12
#     Subtracted bias level of 999.6666666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 13
#     Subtracted bias level of 999.6866666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 14
#     Subtracted bias level of 999.4266666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 15
#     Subtracted bias level of 999.6066666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 16
#     Subtracted bias level of 999.6933333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 17
#     Subtracted bias level of 999.4933333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 18
#     Subtracted bias level of 999.4933333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 19
#     Subtracted bias level of 999.5 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 20
#     Subtracted bias level of 999.5533333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 21
#     Subtracted bias level of 999.3 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 22
#     Subtracted bias level of 999.56 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 23
#     Subtracted bias level of 999.5266666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 24
#     Subtracted bias level of 999.6066666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 25
#     Subtracted bias level of 999.68 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 26
#     Subtracted bias level of 999.5533333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 27
#     Subtracted bias level of 999.3 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 28
#     Subtracted bias level of 999.4866666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 29
#     Subtracted bias level of 999.42 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 30
#     Subtracted bias level of 999.62 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 31
#     Subtracted bias level of 999.5533333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 32
#     Subtracted bias level of 999.6333333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 33
#     Subtracted bias level of 999.4933333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 34
#     Subtracted bias level of 999.62 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 35
#     Subtracted bias level of 999.36 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 36
#     Subtracted bias level of 999.3866666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 37
#     Subtracted bias level of 999.3466666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 38
#     Subtracted bias level of 999.34 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 39
#     Subtracted bias level of 999.2333333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 40
#     Subtracted bias level of 999.2866666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 41
#     Subtracted bias level of 999.58 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 42
#     Subtracted bias level of 999.36 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 43
#     Subtracted bias level of 999.6733333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 44
#     Subtracted bias level of 999.52 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 45
#     Subtracted bias level of 999.32 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 46
#     Subtracted bias level of 999.3466666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 47
#     Subtracted bias level of 999.44 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 48
#     Subtracted bias level of 999.76 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 49
#     Subtracted bias level of 999.5933333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 50
#     Subtracted bias level of 999.4333333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 51
#     Subtracted bias level of 999.3066666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 52
#     Subtracted bias level of 999.3333333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 53
#     Subtracted bias level of 999.6066666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 54
#     Subtracted bias level of 999.6066666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 55
#     Subtracted bias level of 999.6333333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 56
#     Subtracted bias level of 999.4933333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 57
#     Subtracted bias level of 999.56 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 58
#     Subtracted bias level of 999.2666666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 59
#     Subtracted bias level of 999.62 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 60
#     Subtracted bias level of 999.76 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 61
#     Subtracted bias level of 999.4133333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 62
#     Subtracted bias level of 999.4533333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 63
#     Subtracted bias level of 999.5133333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 64
#     Subtracted bias level of 999.2933333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 65
#     Subtracted bias level of 999.9533333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 66
#     Subtracted bias level of 999.1933333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 67
#     Subtracted bias level of 999.6333333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 68
#     Subtracted bias level of 999.5 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 69
#     Subtracted bias level of 999.5866666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 70
#     Subtracted bias level of 999.6066666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 71
#     Subtracted bias level of 999.4866666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 72
#     Subtracted bias level of 999.5533333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 73
#     Subtracted bias level of 999.4 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 74
#     Subtracted bias level of 999.62 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 75
#     Subtracted bias level of 999.4733333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 76
#     Subtracted bias level of 999.5266666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 77
#     Subtracted bias level of 999.5 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 78
#     Subtracted bias level of 999.3733333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 79
#     Subtracted bias level of 999.4933333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 80
#     Subtracted bias level of 999.5133333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 81
#     Subtracted bias level of 999.4466666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 82
#     Subtracted bias level of 999.8133333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 83
#     Subtracted bias level of 999.5266666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 84
#     Subtracted bias level of 999.48 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 85
#     Subtracted bias level of 999.2333333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 86
#     Subtracted bias level of 999.6666666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 87
#     Subtracted bias level of 999.6466666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 88
#     Subtracted bias level of 999.5933333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 89
#     Subtracted bias level of 999.24 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 90
#     Subtracted bias level of 999.5666666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 91
#     Subtracted bias level of 999.4333333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 92
#     Subtracted bias level of 999.7533333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 93
#     Subtracted bias level of 999.6733333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 94
#     Subtracted bias level of 999.6666666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 95
#     Subtracted bias level of 999.5533333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 96
#     Subtracted bias level of 999.6 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 97
#     Subtracted bias level of 999.66 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 98
#     Subtracted bias level of 999.4466666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 99
#     Subtracted bias level of 999.7866666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 100
#     Subtracted bias level of 999.3133333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 101
#     Subtracted bias level of 999.6 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 102
#     Subtracted bias level of 999.3733333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 103
#     Subtracted bias level of 999.5933333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 104
#     Subtracted bias level of 999.14 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 105
#     Subtracted bias level of 999.2333333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 106
#     Subtracted bias level of 999.46 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 107
#     Subtracted bias level of 999.58 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 108
#     Subtracted bias level of 999.8666666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 109
#     Subtracted bias level of 999.4066666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 110
#     Subtracted bias level of 999.66 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 111
#     Subtracted bias level of 999.5666666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 112
#     Subtracted bias level of 999.78 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 113
#     Subtracted bias level of 999.5933333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 114
#     Subtracted bias level of 999.5466666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 115
#     Subtracted bias level of 999.5466666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 116
#     Subtracted bias level of 999.5733333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 117
#     Subtracted bias level of 999.2333333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 118
#     Subtracted bias level of 999.64 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 119
#     Subtracted bias level of 999.46 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 120
#     Subtracted bias level of 999.5466666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 121
#     Subtracted bias level of 999.6333333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 122
#     Subtracted bias level of 999.2933333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 123
#     Subtracted bias level of 999.4066666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 124
#     Subtracted bias level of 999.1666666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 125
#     Subtracted bias level of 999.5866666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 126
#     Subtracted bias level of 999.68 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 127
#     Subtracted bias level of 999.5133333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 128
#     Subtracted bias level of 999.5466666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 129
#     Subtracted bias level of 999.0933333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 130
#     Subtracted bias level of 999.6 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 131
#     Subtracted bias level of 999.4866666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 132
#     Subtracted bias level of 999.2466666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 133
#     Subtracted bias level of 999.6066666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 134
#     Subtracted bias level of 999.2266666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 135
#     Subtracted bias level of 999.4533333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 136
#     Subtracted bias level of 999.4333333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 137
#     Subtracted bias level of 999.5133333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 138
#     Subtracted bias level of 999.64 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 139
#     Subtracted bias level of 999.3533333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 140
#     Subtracted bias level of 999.5733333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 141
#     Subtracted bias level of 999.5133333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 142
#     Subtracted bias level of 999.2866666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 143
#     Subtracted bias level of 999.4933333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 144
#     Subtracted bias level of 999.6466666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 145
#     Subtracted bias level of 999.4266666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 146
#     Subtracted bias level of 999.3333333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 147
#     Subtracted bias level of 999.4 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 148
#     Subtracted bias level of 999.4 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 149
#     Subtracted bias level of 999.4866666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 150
#     Subtracted bias level of 999.3066666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 151
#     Subtracted bias level of 999.4066666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 152
#     Subtracted bias level of 999.7066666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 153
#     Subtracted bias level of 999.7333333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 154
#     Subtracted bias level of 999.6933333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 155
#     Subtracted bias level of 999.6666666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 156
#     Subtracted bias level of 999.6933333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 157
#     Subtracted bias level of 999.5266666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 158
#     Subtracted bias level of 999.5 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 159
#     Subtracted bias level of 999.44 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 160
#     Subtracted bias level of 999.7533333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 161
#     Subtracted bias level of 999.6733333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 162
#     Subtracted bias level of 999.4666666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 163
#     Subtracted bias level of 999.3933333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 164
#     Subtracted bias level of 999.2866666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 165
#     Subtracted bias level of 999.68 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 166
#     Subtracted bias level of 999.34 ADU
#     Corrected for open-shutter smearing
# ...
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 945
#     Subtracted bias level of 999.2266666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 946
#     Subtracted bias level of 999.4666666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 947
#     Subtracted bias level of 999.2866666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 948
#     Subtracted bias level of 999.44 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 949
#     Subtracted bias level of 999.2466666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 950
#     Subtracted bias level of 999.42 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 951
#     Subtracted bias level of 999.3533333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 952
#     Subtracted bias level of 999.38 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 953
#     Subtracted bias level of 999.7133333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 954
#     Subtracted bias level of 999.4066666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 955
#     Subtracted bias level of 999.3733333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 956
#     Subtracted bias level of 999.5133333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 957
#     Subtracted bias level of 999.6066666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 958
#     Subtracted bias level of 999.3933333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 959
#     Subtracted bias level of 999.6866666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 960
#     Subtracted bias level of 999.56 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 961
#     Subtracted bias level of 999.5533333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 962
#     Subtracted bias level of 999.7 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 963
#     Subtracted bias level of 999.4333333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 964
#     Subtracted bias level of 999.42 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 965
#     Subtracted bias level of 999.7466666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 966
#     Subtracted bias level of 999.2733333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 967
#     Subtracted bias level of 999.5266666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 968
#     Subtracted bias level of 999.6466666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 969
#     Subtracted bias level of 999.88 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 970
#     Subtracted bias level of 999.2866666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 971
#     Subtracted bias level of 999.2466666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 972
#     Subtracted bias level of 999.7133333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 973
#     Subtracted bias level of 999.16 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 974
#     Subtracted bias level of 999.42 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 975
#     Subtracted bias level of 999.6 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 976
#     Subtracted bias level of 999.8 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 977
#     Subtracted bias level of 999.74 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 978
#     Subtracted bias level of 999.5866666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 979
#     Subtracted bias level of 999.36 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 980
#     Subtracted bias level of 999.3066666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 981
#     Subtracted bias level of 999.48 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 982
#     Subtracted bias level of 999.44 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 983
#     Subtracted bias level of 999.46 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 984
#     Subtracted bias level of 999.5466666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 985
#     Subtracted bias level of 999.4133333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 986
#     Subtracted bias level of 999.5466666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 987
#     Subtracted bias level of 999.9 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 988
#     Subtracted bias level of 999.2866666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 989
#     Subtracted bias level of 999.6266666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 990
#     Subtracted bias level of 999.3733333333333 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 991
#     Subtracted bias level of 999.5733333333334 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 992
#     Subtracted bias level of 999.5266666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 993
#     Subtracted bias level of 999.4266666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 994
#     Subtracted bias level of 999.3466666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 995
#     Subtracted bias level of 999.62 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 996
#     Subtracted bias level of 999.3666666666667 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 997
#     Subtracted bias level of 999.56 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 998
#     Subtracted bias level of 999.7 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Image # 999
#     Subtracted bias level of 999.4066666666666 ADU
#     Corrected for open-shutter smearing
#     Converted from [ADU] to [electrons] using a Gain of 25.025025025025023 e-/ADU
#     Corrected for PRNU
#     Subtracted background
#     Extract
#     Configuration parameters
#     Analytic PSF
# Done

# %% [markdown]
# What did the photometry script do?
# - Estimate the bias and subtract it
# - Correct for open shutter smearing using the smearing maps
# - Convert from [ADU] to [electrons] using the (FEE and CCD) gain
# - Correct for the flatfield
# - Subtract the background (assumed to be known)
# - Do the weighted mask photometry, assuming the correct star positions

# %%
# %ls -lh photometryOutput.hdf5
# Out:
# -rw-r--r--  1 sara  sara   141M Sep 19 09:40 photometryOutput.hdf5

# %% [markdown]
# ### What does a photometry output HDF5 file look like?

# %%
photFile = h5py.File("photometryOutput.hdf5")

# %%
for group in photFile["/"]:
    print(group)
# Out:
# Masks
# Photometry

# %%
for group in photFile["/Photometry"]:
    print(group)
# Out:
# Exposure000000
# Exposure000001
# Exposure000002
# Exposure000003
# Exposure000004
# Exposure000005
# Exposure000006
# Exposure000007
# Exposure000008
# Exposure000009
# Exposure000010
# Exposure000011
# Exposure000012
# Exposure000013
# Exposure000014
# Exposure000015
# Exposure000016
# Exposure000017
# Exposure000018
# Exposure000019
# Exposure000020
# Exposure000021
# Exposure000022
# Exposure000023
# Exposure000024
# Exposure000025
# Exposure000026
# Exposure000027
# Exposure000028
# Exposure000029
# Exposure000030
# Exposure000031
# Exposure000032
# Exposure000033
# Exposure000034
# Exposure000035
# Exposure000036
# Exposure000037
# Exposure000038
# Exposure000039
# Exposure000040
# Exposure000041
# Exposure000042
# Exposure000043
# Exposure000044
# Exposure000045
# Exposure000046
# Exposure000047
# Exposure000048
# Exposure000049
# Exposure000050
# Exposure000051
# Exposure000052
# Exposure000053
# Exposure000054
# Exposure000055
# Exposure000056
# Exposure000991
# Exposure000992
# Exposure000993
# Exposure000994
# Exposure000995
# Exposure000996
# Exposure000997
# Exposure000998
# Exposure000999
# time

# %%
for dataset in photFile["/Photometry/Exposure000000"]:
    print(dataset)
# Out:
# NSR
# Vmag
# estimatedFlux
# maskSize
# numContaminants
# starID
# trueCol
# trueFlux
# trueRow
# varFlux

# %% [markdown]
# Get the photometry done on the very first image. Fluxes are expressed in [electrons/exposure]

# %%
starID           = array(photFile["/Photometry/Exposure000000/starID"])
inputFlux        = array(photFile["/Photometry/Exposure000000/trueFlux"])
estimatedFlux    = array(photFile["/Photometry/Exposure000000/estimatedFlux"])
varEstimatedFlux = array(photFile["/Photometry/Exposure000000/varFlux"])
Vmag             = array(photFile["/Photometry/Exposure000000/Vmag"])
NSR              = array(photFile["/Photometry/Exposure000000/NSR"])
maskSize         = array(photFile["/Photometry/Exposure000000/maskSize"])

# %% [markdown]
# The theoretical photon noise limit is not saved in HDF5 but is easily computable using the 'inputFlux'. If we sort the photon noise value, we can plot them in one smooth line. Note the 'inputFlux' stored in the HDF5 file is an electron flux, already taking into account the transmission efficiency, and the QE.

# %%
photonLimit = inputFlux/sqrt(inputFlux)
sorted = argsort(photonLimit)[::-1]

# %% [markdown]
# Plot the Signal-to-Noise ratio (per exposure) of all stars in the subfield, together with theoretical photon noise limit.

# %%
fig = plt.figure(figsize = (10, 10))
plt.scatter(Vmag, 1.0 / NSR)
# plt.scatter(Vmag, SNR)
plt.plot(Vmag[sorted], photonLimit[sorted], c="r")
plt.grid(True, which='major', axis='both', linestyle='-', color='gray')
plt.xlabel("V magnitude")
plt.ylabel("S/N")
# plt.xlim(7,15)
# plt.ylim(0,1600)
# Out:
# Text(0, 0.5, 'S/N')

# %% [markdown]
# The large S/N values at the faint end are caused by nearby brighter stars that significantly contaminate the flux level. Even for lower magnitudes, the S/N ratio is well below the photon noise limit because of the weighted photometry gives a lower weight to the tails of the PSF. You can of course play with the PSF-width you feed to phot.photometr(), to verify if it gives better results. For the very brightest stars, the electrons flowing away due to blooming are not recovered when extracting the stellar flux.

# %% [markdown]
# ## Extract the time series of one particular star

# %% [markdown]
# We choose one particular 11th magnitude star

# %%
print(Vmag)
print(starID)
plt.plot(starID, Vmag, 'k+')
print(Vmag[Vmag==11.0])
# Out:
# [11.742 13.201 10.564 ... 14.545 14.345 14.045]
# [15553 15556 15563 ... 25970 25972 25974]
# []

# %%
myStarID = 15553#9789

# %%
time, trueRow, trueCol, trueFlux, outputFlux = phot.getPhotometryTimeSeries("photometryOutput.hdf5", myStarID)

# %%
flux = outputFlux

# %% [markdown]
# Convert the absolute flux [electrons/exposure] into a relative flux [ppm]

# %%
relativeFlux = (flux - flux.mean())/flux.mean()*1.e6

# %%
fig = plt.figure(figsize = (10, 10))
plt.plot(time, flux)
plt.xlabel("Time")
plt.ylabel("Flux [e-/exp]")
# Out:
# Text(0, 0.5, 'Flux [e-/exp]')

# %%
fig = plt.figure(figsize = (10, 10))
plt.plot(time, relativeFlux)
plt.xlabel("Time")
plt.ylabel("Relative flux [ppm]")
# Out:
# Text(0, 0.5, 'Relative flux [ppm]')

# %% [markdown]
# ## Generate stellar granulation

# %%
time =  array(outputFile["/StarPositions/Time"])

# %%
timeScale = array([2060.0])       # sec
varScale  = array([520.0])        # ppm

# %% [markdown]
# More decent values for Sun-like stars can be obtained from Pallé, P.L., Roca-Cortés, T., & Jimenez, A. 1999, ASP
# Conf. Ser. 173, Stellar Structure: Theory and Test of Convective Energy Transport, ed. A. Gimenez, E.F. Guinan, &
# B. Montesinos, 297.

# %%
granulation = noise.redNoise(time, timeScale, varScale)
# Out:
# Simulating 1 component(s)
# Kicktimestep = 20.6
# Warming up...
# Simulating red noise component(s)

# %%
fig = plt.figure(figsize = (10, 10))
plt.plot(time, granulation)
plt.xlabel("Time [s]")
plt.ylabel("Signal [ppm]")
# Out:
# Text(0, 0.5, 'Signal [ppm]')

# %% [markdown]
# ## Generate an exoplanet signature

# %%
import transits

# %%
t0 = 5 * 3600.
flatPartDuration = 3 * 3600.
transitDuration  = 4 * 3600.
orbitalPeriod    = 36 * 3600.
relativeDepth    = 0.001         # 1000 ppm
phase, signal, deltaMagnitude = transits.simpleTransit(time, t0, flatPartDuration, transitDuration, orbitalPeriod, relativeDepth)

# %%
fig = plt.figure(figsize = (10, 10))
plt.plot(time, signal)
plt.ylim(0.997, 1.002)
plt.ticklabel_format(style='plain', axis='y', useOffset=False)

# %% [markdown]
# ## Combine everything

# %%
flux *= signal
relativeFlux = (flux - flux.mean())/flux.mean()*1.e6     # ppm
relativeFlux += granulation

# %% [markdown]
# Bin the time series to make the structure inside more clear

# %%
binnedMean, binEdges, binNumber = binned_statistic(time, relativeFlux, statistic='mean', bins=100)
binCenters = (binEdges[1:] + binEdges[:-1])/2.0

# %% [markdown]
# Now plot the original time series as well as the binned time series.

# %%
fig = plt.figure(figsize = (10, 10))
plt.plot(time, relativeFlux, c='b')
plt.plot(binCenters, binnedMean, c='w', linewidth=3)
plt.xlabel("Time [s]")
plt.ylabel("Relative Flux [ppm]")
# Out:
# Text(0, 0.5, 'Relative Flux [ppm]')

# %% [markdown]
# ## Plot the power spectral density of the time series

# %%
def FFTpowerdensity(signal, timestep):

    fourier = fft.rfft(signal)
    Ntime = len(signal)
    Nfreq = len(fourier)
  
    powerdensity = abs(fourier)**2 / Ntime * timestep
    freq = arange(float(Nfreq)) / (Nfreq-1) * 0.5 / timestep
  
    return (freq, powerdensity)

# %%
freq, psd = FFTpowerdensity(relativeFlux, (time[1]-time[0])*1.e-6)

# %% [markdown]
# The 1.e-6 is to convert the time unit from [s] to [Ms], so that the frequency is in [microHz].

# %%
fig = plt.figure(figsize = (10, 10))
plt.loglog(freq, psd)
plt.xlabel("Frequency [microHz]")
plt.ylabel("Power Spectral Density [ppm^2/microHz]")
# Out:
# Text(0, 0.5, 'Power Spectral Density [ppm^2/microHz]')
