# %%
# %matplotlib inline

# %%
import tables

# %%
import matplotlib.pyplot as plt

# %%
out = tables.open_file('/Users/rik/Work/PLATO/Simulations/Run01.hdf5')

# %%
out.root
# Out:
# / (RootGroup) ''
#   children := ['InputParameters' (Group), 'Images' (Group), 'StarCatalog' (Group), 'Vignetting' (Group), 'StarPositions' (Group), 'Telescope' (Group), 'ACS' (Group), 'Version' (Group), 'SmearingMaps' (Group), 'Flatfield' (Group), 'BiasMaps' (Group), 'Background' (Group), 'PSF' (Group)]

# %%
img0 = out.root.Images.image000000

# %%
plt.imshow(img0)

# %%
out.root.StarCatalog
# Out:
# /StarCatalog (Group) ''
#   children := ['starIDs' (Array), 'yFPmm' (Array), 'RA' (Array), 'rowPix' (Array), 'colPix' (Array), 'Vmag' (Array), 'xFPmm' (Array), 'Dec' (Array)]

# %%
out.root.InputParameters.Camera._v_attrs
# Out:
# /InputParameters/Camera._v_attrs (AttributeSet), 5 attributes:
#    [FocalLength := 0.24712595000000001,
#     FocalPlaneOrientation := 0.0,
#     PlateScale := 0.83330000000000004,
#     ThroughputBandwidth := 400.0,
#     ThroughputLambdaC := 600.0]

# %%
out.root.InputParameters.PSF._v_attrs.Model
# Out:
# b'Gaussian'

# %%
out.root.InputParameters.PSF._v_attrs._v_attrnames
# Out:
# ['Model']
