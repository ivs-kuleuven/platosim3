# %% [markdown]
# # Performance of payload

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
import glob
import scipy
import numpy as np
import pandas as pd
import scipy as sp
from scipy.stats import binned_statistic
import statsmodels.api as sm
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from scipy.optimize import curve_fit
from scipy.ndimage import median_filter
from matplotlib import patches
from matplotlib.ticker import FuncFormatter

# PlatoSim extra
import natsort
from astropy import units as u
from astropy.coordinates import SkyCoord
from pathlib import Path
from tqdm import tqdm 

# PlatoSim libraries
import platosim.plot       as pt
import platosim.noise      as ns
import platosim.utilities  as ut
import platosim.statistics as st
from platosim.simfile      import SimFile
from platosim.simulation   import Simulation
from platosim.lightcurve   import LightCurve
from platosim.matplotlibrc import setup_paper
setup_paper()

import warnings
warnings.simplefilter("ignore")

# %%
# Define paths
fdir = '/lhome/nicholas/Nextcloud/paperMOCKA/figures'
vdir = '/lhome/nicholas/software/PlatoSim3/inputfiles/data_varsim'
path = f'/lhome/nicholas/software/workdir/mocka/simulations/analysis/GDOR'
# patha = f'{path}/affogato'
# pathc = f'{path}/cortado'
# pathd = f'{path}/doppio'
# pathv = f'{path}/varsource'

# %% [markdown]
# ## Plot light curve

# %%
star = f'{1}'.zfill(9)
idir = f'{path}/output_clean/{star}'

# Load ligth curve object
lcs = LightCurve(idir, 'multi')

# Check sim info
N = len(lcs.files('ftr')) / 2.
lc = LightCurve(lcs.files('ftr')[0])

# Simulation table
ds = lc.star()
ds
# Out:
# ID                           1
# gaiaDR3    5303012479913170560
# ra                  134.532937
# dec                 -60.020178
# mag                  15.316477
# group                        1
# camera                       1
# quarter                      1
# ccd                          2
# xCCD               1851.767959
# yCCD                800.446693
# rOA                  17.148201
# xFP                  -68.07196
# yFP                 -34.631823
# ncon                         3
# SPR                   0.000159
# Name: 0, dtype: object

# %%
# Check predicted NSR camera and mission level
tdur = 3600
noise_jitter         = ut.getJitterNoiseLimitNSR(rms=0.037, tdur=tdur, level='camera')
noise_photon_camera  = ut.getPhotonNoiseLimitNSR(ds.mag, passband='P', ncam=1, tdur=tdur)
noise_photon_mission = ut.getPhotonNoiseLimitNSR(ds.mag, passband='P', ncam=N, tdur=tdur)
noise_background     = ut.getBackgroundNoiseLimitNSR(ds.mag, passband='P', tdur=tdur)
noise_camera  = noise_jitter + noise_photon_camera  + noise_background
noise_mission = noise_jitter + noise_photon_mission + noise_background

# print(f'Max ampl    : {dp.Amax_mag[0] * 1.037e6:.0f} ppm')
print(f'NSR camera  : {noise_camera:.0f} ppm')
print(f'NSR mission : {noise_mission:.0f} ppm ({int(N)} N-CAM)')
# Out:
# NSR camera  : 3558 ppm
# NSR mission : 2955 ppm (6 N-CAM)

# %%
fig, ax = lcs.plot_multi(suffix='ftr', group=False, camera=False, quarter=False, 
                         flux_median=144, alpha=0.1, figsize=(9,4))
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# ---
# ## NSR(P)
# ---

# %% [markdown]
# ### NSR(P) at camera level

# %%
lcs = LightCurve(f'{path}/output_clean', mode="multi")
ofile = f'{path}/nsr_per_camera_EOL.ftr'
lcs.run_NSRvsMag_analysis_perCamera(ofile, suffix="ftr", quarter=8);
# Out:
#  13%|██████▋                                           | 533/4000 [00:40<04:22,
# [Error]: No files found with suffix ftr!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
# Load results
df = pd.read_feather(ofile)

# Order after contaminants
df = df.sort_values(by=['SPR'], ascending=True)

# Plot all data together
fig, ax = pt.plotNSRvsMagnitude(df, column="SPR", passband='P', residuals="multi", 
                                show_ncam_noise_limits=1, show_saturation_limits=True,
                                show_targets=True, legend=True, grid=False, 
                                cmap='rainbow', figsize=(10, 8))

# Plot detection limits of typical amplitudes
# ax.axhline(y=(10**(0.4*1e-3*15)-1)*1e6, color="b", alpha=0.7, linestyle=':',
#           zorder=0, label=r'$\delta$ Sct/$\beta$ Cep: $A_{\rm bulk} = 15$ mmag')
# ax.axhline(y=(10**(0.4*1e-3*10)-1)*1e6, color="b", alpha=0.7, linestyle='--', 
#            zorder=10, label=r'$\gamma$ Dor/SPB : $A_{\rm max} = 10$ mmag')
# ax.axhline(y=(10**(0.4*1e-3*1)-1)*1e6, color="b", alpha=0.7, linestyle='-.',
#           zorder=10, label=r'$\gamma$ Dor/SPB : $A_{\rm bulk} = 1$ mmag')

# Settings
ax.set_title('Noise budget at camera level for BOL')
ax.set_xlim(7.0, 17)
# ax.set_ylim(0, 20000)
plt.legend()

# Save figure
# fig.savefig('nsrCameraLevel.png', bbox_inches='tight', dpi=300);
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### NSR(P) at mission level

# %%
lcs = LightCurve(f'{path}/output_clean', mode="multi")
ofile = f'{path}/nsr_per_star_BOL.ftr'
# lcs.run_NSRvsMag_analysis_perStar(ofile, suffix="ftr", quarter=1);

# %%
# Load results
df = pd.read_feather(ofile)

# Order after contaminants
df = df.sort_values(by=['SPR'], ascending=False)
# df.mag = ut.passbandConversionV2P(df.mag, 6000, inverse=True, method='fialho')

# Plot all data together
fig, ax = pt.plotNSRvsMagnitude(df, column="ncam", passband='P', residuals=False, 
                                show_ncam_noise_limits=False, show_saturation_limits=True,
                                show_targets=True, legend=True, grid=False, 
                                cmap='rainbow', figsize=(11, 8))

# Plot detection limits of typical amplitudes
ax.axhline(y=10000, color="m", alpha=0.7, linestyle='-.', 
           zorder=5, label=r'$\gamma$ Dor: $\; A_{\rm max} = 10$ ppt')
ax.axhline(y=1728, color="g", alpha=0.7, linestyle='--',
          zorder=5, label=r'$\delta$ Sct: \, $A_{\rm bulk} = 1728$ ppm')
ax.axhline(y=1545, color="c", alpha=0.7, linestyle='--',
          zorder=5, label=r'$\beta$ Cep: $A_{\rm bulk} = 1545$ ppm')
ax.axhline(y=1214, color="b", alpha=0.7, linestyle='--',
          zorder=5, label=r'SPB: \,\,\, $A_{\rm bulk} = 1214$ ppm')
ax.axhline(y=257, color="m", alpha=0.7, linestyle='--',
          zorder=5, label=r'$\gamma$ Dor: $A_{\rm bulk} = 257$ ppm')

# Settings
ax.set_title('Noise budget at camera level for BOL')
ax.set_xlim(7.0, 17)
# ax.set_ylim(0, 20000)
plt.legend();

# Save figure
# fig.savefig('nsrCameraLevel.png', bbox_inches='tight', dpi=300);
# Out:
# <img src="data:image/png;base64,..." width="1100">

# %%
# Test single light curve
files_final = natsort.natsorted(glob.glob(f'{path}/clean/final/*'))
lc = LightCurve(files_final[0], mode="single")

df = lc.bin_lc(tbin=600, t0=0, t1=1)
noise = (1 - df.flux) * 1e6
NSR = np.std(noise) / np.sqrt(86400/600)
NSR

# %%
def getReducedNSR(path):
    
    idir = '/lhome/nicholas/software/workdir/mocka'
    folders = natsort.natsorted(glob.glob(f'{path}/*'))
    dx = pd.DataFrame()
    
    for f,i in zip(folders, range(len(folders))):
        
        # Load and reduce light curve
        star = Path(folders[i]).stem
        try:
            lcs = LightCurve(f, 'multi')
        except: 
            pass
        else:
            lc = lcs.merge(suffix='hdf5', 
                   verbose=True,
                   detrend='poly',
                   flux_group_mean=True, 
                   clip=False, #df.mag.iloc[0], 
                   binsize=0.2, 
                   flux_offset=True, 
                   flux_err=True, 
                   ofile=f'{path}/lc_{star}.ftr')

            # Introduce data gaps
            df = lc.gaps(f'{idir}/input/instrumentGAP.tab', replace=True)
            df = df.dropna()
            df.time /= 86400

            # Load variable template
            dp = pd.read_feather(f'{f}/../../varsource/{star}/varsource_001_parameters.ftr')
            dm = pd.read_feather(f'{f}/../../varsource/{star}/varsource_001_pulsations.ftr')
            dv = pd.DataFrame()
            dv['time'] = df.time
            dv['dmag'] = ns.timeSeriesFromFourier(df.time, dm.freq, dm.ampl, dm.phase, power=2.2)
            dv['flux'] = (10**(-0.4*dv.dmag) - 1) * 1e3

            # Compute the residuals
            df['flux_res'] = (df.flux -1)*1e3 - dv.flux

            # Compute NSR for star
            NSR_res = np.std(df.flux_res) * 1e3
            RMS_res = ut.medianAbsoluteDeviation(df.flux_res) * 1e3 

            
            # Store in data frame
            dx0 = pd.DataFrame({'Pmag': dp.Pmag,
                                'NSR': NSR,
                                'ncam': dt.shape[0]/8,
                                'rOA': dt.rOA.mean(),
                                'SPR': dt.SPR.mean(),
                                })
            dx = pd.concat([dx, dx0])

    return dx
        
# RUN SCRIPT
idir = f'/lhome/nicholas/software/workdir/mocka/simulations/tests/test_hdf5'
# df = getReducedNSR(idir)

# %%
def getNSR(path, sample='affogato'):
    
    # Load light curve object for the first star only and unpack the data
    pathv = f'{path}/varsource'
    files_param = natsort.natsorted(glob.glob(f'{path}/varsource/parameters/*'))
    files_pulsa = natsort.natsorted(glob.glob(f'{path}/varsource/pulsations/*'))
    files_table = natsort.natsorted(glob.glob(f'{path}/{sample}/table/*'))
    files_final = natsort.natsorted(glob.glob(f'{path}/{sample}/final/*'))
    dx = pd.DataFrame()
    
    for i in tqdm(range(len(files_final)), bar_format=ut.tqdmBar()):
        
        # Load files from for varsource
        dp = pd.read_feather(files_param[i])
        dt = pd.read_feather(files_table[i])
        dm = pd.read_feather(files_pulsa[i])
        
        # Load data and bin
        try:
            lc = LightCurve(files_final[i], mode="single")
        except: 
            pass
        else:
            # Bin data
            df = lc.bin_lc(tbin=600, t0=0, t1=100)
            df.time /= 86400
            df.flux = (df.flux - 1) * 1e6

            # Load variable template
            df['dmag_var'] = ns.timeSeriesFromFourier(df.time, dm.freq, dm.ampl, dm.phase, power=2.2)
            df['flux_var'] = (10**(-0.4*df.dmag_var) - 1) * 1e6
            
            # Compute residuals
            df['flux_res'] = df.flux - df.flux_var   
            df = df.dropna()
            NSR = ut.medianAbsoluteDeviation(df.flux_res.to_numpy())

            # Store in data frame
            dx0 = pd.DataFrame({'Pmag': dp.Pmag,
                                'NSR': NSR,
                                'ncam': dt.shape[0]/8,
                                'rOA': dt.rOA.mean(),
                                'SPR': dt.SPR.mean(),
                               })
            dx = pd.concat([dx, dx0])

    # Return data frame
    return dx


# Fetch NSR for all stars
path = f'/lhome/nicholas/software/workdir/mocka/simulations/analysis/GDOR'
# path = f'/lhome/nicholas/software/workdir/mocka/simulations/output_clean'
df = getNSR(path, 'clean')

# %%
def getNSR(project, data_dir):
    
    """NSR estimate from fully reduced feather light curves.
    """
    
    # Define paths and 
    path = Path(os.getenv('PLATO_WORKDIR')) / project
    idir = path / 'input'
    sdir = path / data_dir
    vdir = sdir.parents[0] / 'varsource'
    
    # Fetch filenames
    files = natsort.natsorted(glob.glob(f'{sdir}/lc_**.ftr'))
    dx = pd.DataFrame()
    
    for file_i, i in zip(files, tqdm(range(len(files)), bar_format=ut.tqdmBar())):
        
        # Load and reduce light curve
        f = Path(file_i)
        star = f.stem[3:]
        lc = LightCurve(f, 'single')
        
        # Introduce data gaps
        df = lc.data().dropna()
        
        # Load variable template
        dp = pd.read_feather(vdir / f'parameters/parameters_{star}_001.ftr')
        dm = pd.read_feather(vdir / f'pulsations/pulsations_{star}_001.ftr')
        dv = pd.DataFrame()
        dv['time'] = df.time
        dv['dmag'] = ns.timeSeriesFromFourier(df.time, dm.freq, dm.ampl, dm.phase, power=2.2)
        dv['flux'] = (10**(-0.4*dv.dmag) - 1) * 1e6
        
        # Compute the residuals
        df['flux'] = (df.flux - 1) * 1e6 #- dv.flux
        lc = LightCurve(df, 'multi')    
        NSR = lc.getNSR(influx='ppm', unit='ppm', binhour=1)
        
        # Store in data frame
        dx0 = pd.DataFrame({'Pmag': dp.Pmag,
                            'NSR': NSR,
                            'ncam': dp['ncams'],
                            'ID': star,
#                             'rOA': dp.rOA.mean(),
#                             'SPR': dp.SPR.mean(),
                            })
        dx = pd.concat([dx, dx0])

    return dx
        
# RUN SCRIPT
idir = 'simulations/analysis/GDOR/feather_clean'
df = getNSR(project='mocka', data_dir=idir)
# Out:
#  98%|████████████████████████████████████████████████▊ | 39/40 [03:07<00:04,  4.

# %%
df
# Out:
#         Pmag          NSR  ncam         ID
# 0  13.936833  2428.530609     6  000000001
# 0  11.653350   171.117933     6  000000002
# 0  10.915871   116.774509     6  000000003
# 0  11.040159   125.884931     6  000000004
# 0  12.522381   305.905159     6  000000005
# 0  12.607368   332.086403     6  000000006
# 0  14.299427  1975.994376     6  000000007
# 0  12.775543   411.426034     6  000000008
# 0  13.046778   540.430427     6  000000009
# 0  12.776801   446.650934     6  000000010
# 0  13.734067  1164.153856     6  000001001
# 0  12.142799    81.553501     6  000001002
# 0  10.325019    49.987169     6  000001003
# 0  13.348340    98.348275     6  000001004
# 0  13.536985   185.328309     6  000001005
# 0  11.294083   166.556124     6  000001006
# 0  12.150262  1905.293559     6  000001007
# 0  12.743701   208.518388     6  000001008
# 0  11.907359   444.716795     6  000001009
# 0  11.610444   205.679542     6  000001010
# 0  12.332234  1284.880090     6  000002001
# 0  13.039386   127.326224     6  000002002
# 0  12.509201    88.069550     6  000002003
# 0  12.507942    79.206354     6  000002004
# 0   9.092570    94.600327     6  000002005
# 0  11.628833   103.998994     6  000002006
# 0  13.296932  1905.560193     6  000002007
# 0  12.097004   144.672396     6  000002008
# 0  13.826427   185.270243     6  000002009
# 0  11.455901   186.531526     6  000002010
# 0  11.075161   691.664774    12  000003001
# 0  12.746132    66.707819    12  000003002
# 0  11.584216    43.352918    12  000003003
# 0  11.881094   131.414119    12  000003004
# 0  12.204982    81.526435    12  000003005
# 0  10.922203   156.278022    12  000003006
# 0  10.927243  1697.114831    12  000003007
# 0  12.946614   157.673878    12  000003008
# 0  12.628003   263.918174    12  000003009
# 0  12.218895   107.754843    24  000003010

# %% [markdown]
# ## Plot NSR

# %%
# Single camera limits
mag = np.linspace(7, 17, 100)

noise_jitter_1h     = ut.getJitterNoiseLimitNSR(rms=0.037, tdur=3600, level='camera')
noise_photon_1h     = ut.getPhotonNoiseLimitNSR(mag, passband='P', ncam=1, tdur=3600)
noise_background_1h = ut.getBackgroundNoiseLimitNSR(mag, passband='P', tdur=3600)
noise_1h = noise_jitter_1h + noise_photon_1h + noise_background_1h

noise_jitter_10min     = ut.getJitterNoiseLimitNSR(rms=0.037, tdur=600, level='camera')
noise_photon_10min     = ut.getPhotonNoiseLimitNSR(mag, passband='P', ncam=1, tdur=600)
noise_background_10min = ut.getBackgroundNoiseLimitNSR(mag, passband='P', tdur=600)
noise_10min = noise_jitter_10min + noise_photon_10min + noise_background_10min

# %%
# Plot NSR(P) at "camera level" for cadence 10min
fig, ax = plt.subplots(1,1,figsize=(9,7))

scat = ax.scatter(df.Pmag, df.NSR, c=df.ncam,  marker='o', s=15, lw=0.3, ec='w', cmap='rainbow')
cbar = plt.colorbar(scat, extend='both', pad=0.02, shrink=0.95)
cbar.set_label(r'$n_{\rm NCAM}$')

ax.plot(mag, noise_10min, '-', c='orange', lw=2,  zorder=2)
ax.plot(mag, noise_background_10min, '--', c='k', lw=1.5, zorder=2)
ax.plot(mag, noise_photon_10min, '-.', c='k', lw=1.5)
ax.axhline(y=noise_jitter_10min, c="k", ls=":", lw=1.5, zorder=2)

ax.set_yscale('log')
ax.set_title('Noise mission level for 10 min cadence')
ax.set_xlabel(r'PLATO magnitude, $P$')
ax.set_ylabel(r'NSR [ppm h$^{-1/2}$]')
ax.set_xlim(mag[0], mag[-1])
plt.tight_layout()

# Save figure
# fig.savefig('nsrInstrumentLevel.png', bbox_inches='tight', dpi=300);
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
# Plot NSR(P) at "camera level" for cadence 1h
fig, ax = plt.subplots(1,1,figsize=(10,7))

scat = ax.scatter(df.Pmag, df.NSR, c=df.ncam,  marker='o', s=15, lw=0.3, ec='w', cmap='rainbow')
cbar = plt.colorbar(scat, extend='both', pad=0.02, shrink=0.95)
cbar.set_label(r'$n_{\rm NCAM}$')

ax.plot(mag, noise_1h, '-', c='orange', lw=2,  zorder=2)
ax.plot(mag, noise_background_1h, '--', c='k', lw=1.5, zorder=2)
ax.plot(mag, noise_photon_1h, '-.', c='k', lw=1.5)
ax.axhline(y=noise_jitter_1h, c="k", ls=":", lw=1.5, zorder=2)

ax.set_yscale('log')
ax.set_xlabel(r'PLATO magnitude, $P$')
ax.set_ylabel(r'NSR [ppm h$^{-1/2}$]')
ax.set_xlim(mag[0], mag[-1])
plt.tight_layout()

# Save figure
# fig.savefig('nsrInstrumentLevel.png', bbox_inches='tight', dpi=300);

# %%
fig, ax = plt.subplots(1,1,figsize=(9,7))

scat = ax.scatter(df.Pmag, df.NSR, c=df.SPR,  marker='o', s=15, lw=0.3, ec='w', cmap='rainbow')
cbar = plt.colorbar(scat, extend='both', pad=0.02, shrink=0.95)
cbar.set_label(r'$n_{\rm NCAM}$')

ax.plot(mag, noise_10min/np.sqrt(6), '-', c='k', lw=1.5,  zorder=2)
ax.plot(mag, noise_10min/np.sqrt(12), '--', c='k', lw=1.5,  zorder=2)
ax.plot(mag, noise_10min/np.sqrt(18), '-.', c='k', lw=1.5,  zorder=2)
ax.plot(mag, noise_10min/np.sqrt(24), ':', c='k', lw=1.5,  zorder=2)

ax.axhline(y=(10**(0.4*1e-3*10)-1)*1e6, color="m", alpha=0.7, linestyle=':', 
           zorder=0, label=r'$\gamma$ Dor/SPB : $A_{\rm max} = 10$ mmag')
ax.axhline(y=(10**(0.4*1e-3*1)-1)*1e6, color="m", alpha=0.7, linestyle='--',
          zorder=0, label=r'$\gamma$ Dor/SPB : $A_{\rm bulk} = 1$ mmag')

ax.axhline(y=(10**(0.4*1e-3*50)-1)*1e6, color="b", alpha=0.7, linestyle=':', 
           zorder=0, label=r'$\delta$ Sct/$\beta$ Cep: $A_{\rm max} = 50$ mmag')
ax.axhline(y=(10**(0.4*1e-3*15)-1)*1e6, color="b", alpha=0.7, linestyle='--',
          zorder=0, label=r'$\delta$ Sct/$\beta$ Cep: $A_{\rm bulk} = 15$ mmag')

ax.set_yscale('log')
ax.set_xlabel(r'PLATO magnitude, $P$')
ax.set_ylabel(r'NSR [ppm h$^{-1/2}$]')
ax.set_xlim(mag[0], mag[-1])
plt.legend()
plt.tight_layout()


# Settings
# fig, ax = pt.plotNSRvsMagnitude(df, column="ncam", passband='V', residuals="multi", 
#                                 legend=True, grid=False, figsize=(9,6))
# Set axes limits
# ax.set_title('b) Noise budget at instrument level for BOL')
# ax.set_xlim(7, 12.77)
# ax.set_ylim(5, 340)
# We change the fontsize of minor ticks label 
# ticks_minor = [5, 6, 20, 30, 40, 50, 60, 70, 200, 300]
# ax.yaxis.set_minor_locator(mticker.FixedLocator(ticks_minor))
# ax.set_yticklabels(ticks_minor)
# ticks_major = [1, 10, 100, 1000]
# ax.yaxis.set_major_locator(mticker.FixedLocator(ticks_major))
# ax.set_yticklabels(ticks_major);
# Save figure
# fig.savefig('nsrInstrumentLevel.png', bbox_inches='tight', dpi=300);
