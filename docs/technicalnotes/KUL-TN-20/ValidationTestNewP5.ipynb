# %%
# Alow changes to the PlatoSim code outside this notebook
# %load_ext autoreload
# %autoreload 2

# Configure figure in notebook
# %matplotlib notebook

# %%
import os
import sys
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# PlatoSim libraries
from platosim.lightcurve import LightCurve
from platosim.matplotlibrc import setup_notebook
setup_notebook()

# %%
# Load all data for a single star
idir = "/lhome/nicholas/software/workdir/kul20/test/starID46/platosim"
lc = LightCurve(f"{idir}/000000046_Ncam1.1_Q23.hdf5")

# %%
fig, ax = lc.plot(median_filter=1)
ax.set_title('PlatoSim');
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
# Load all data for a single star
idir = "/lhome/nicholas/software/workdir/kul20/test/starID46/pipeline"
lc = LightCurve(f"{idir}/000000046_Ncam1.1_Q23.ftr")
df = lc.data()
df
# Out:
#          index          time          flux        xc        yc  flux_cor
# 0            0  1.710720e+08  41165.277657  2.862306  2.916242  1.240942
# 1            1  1.710720e+08  42994.956283  2.858908  2.919346  1.239873
# 2            2  1.710721e+08  43065.846040  2.861064  2.914622  1.240703
# 3            3  1.710721e+08  43861.297305  2.864560  2.913909  1.241307
# 4            4  1.710721e+08  43639.072413  2.858951  2.912471  1.241846
# ...        ...           ...           ...       ...       ...       ...
# 304123  304123  1.786751e+08  43493.385953  2.727292  2.829919  1.182959
# 304124  304124  1.786751e+08  43186.859638  2.719661  2.830789  1.183311
# 304125  304125  1.786751e+08  43263.821543  2.723644  2.835980  1.183217
# 304126  304126  1.786752e+08  43261.756814  2.725778  2.836167  1.183604
# 304127  304127  1.786752e+08  43243.649390  2.727125  2.837157  1.183874
#
# [304128 rows x 6 columns]

# %%
# fig, ax = lc.plot(median_filter=1)
plt.figure()
plt.plot(df.time, df.flux/df.flux_cor, 'r.', alpha=0.05)
ax.set_title('PlatoSim + L1 pipeline')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
