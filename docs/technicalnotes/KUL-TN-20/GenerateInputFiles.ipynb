# %% [markdown]
# # Input files for KUL-TN-21

# %% [markdown]
# ### Setup notebook

# %%
# Alow changes to the PlatoSim code outside this notebook
# %load_ext autoreload
# %autoreload 2

# Configure figure in notebook
# %matplotlib notebook

# %% [markdown]
# ### Imports

# %%
# Second part libraries
import os
import sys
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage import median_filter

# PlatoSim libraries
from platosim.simfile import SimFile
from platosim.plot import plotPhotometry
from platosim.utilities import errorcode, normalize
from platosim.lightcurve import LightCurve
from platosim.matplotlibrc import setup_notebook
setup_notebook()

# %% [markdown]
# ---
# ## Generate AOCS jitter file
# ---

# %% [markdown]
# ---
# ## Generate TED file
# ---

# %%
data = np.loadtxt("/lhome/nicholas/software/workdir/kul20/input/TED_4mHz_6arcsec_180d_Q23-24.txt")

# %%
plt.figure()
plt.plot(data[:,0]/86400, data[:,1], "-",  label="Yaw")
plt.plot(data[:,0]/86400, data[:,2], "--", label="Pitch")
plt.plot(data[:,0]/86400, data[:,3], ":",  label="Roll")
plt.ylabel("TED [arcsec]")
plt.xlabel("Time [days]")
plt.legend()
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ---
# ## Generate TE file
# ---

# %%
data = np.loadtxt("/lhome/nicholas/software/workdir/kul20/input/TE_4mHz_4mas_180d_Q23-24.txt")

# %%
plt.figure()
plt.plot(data[:,0]/86400, data[:,1], "-")
plt.ylabel("TE [\%]")
plt.xlabel("Time [days]")
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ---
# ## Generate misalignment models
# ---

# %%
# Choose directory to save and unpack data
idir = '/lhome/nicholas/software/workdir/jitterImpact/input/'

# Constants
ppmh = 144   # For a cadence of 25s
model = 'y ~ x'
ms, aa = 3, 0.1

# Perfect pointing to provisional SPF (ICRS - equatorial)
ra  = 86.79870508
dec = -46.39594703
rot = -4.0
ICRS = np.array([ra, dec, rot])
quarters = np.array([1, 2, 3, 4, 5, 6, 7, 8])
sigma = 3

# %% [markdown]
# ### Generate PRE file

# %% [markdown]
# ### Generate APE file

# %% [markdown]
# ---
# ## Microscanning
# ---

# %%
# Load file
filename = os.getenv('PLATO_WORKDIR') + '/input/spiral_8Hz_airbus_3h.dat'
filename = os.getenv('PLATO_WORKDIR') + '/input/spiral_8Hz_airbus_3h.dat'

# filename = os.getenv('PLATO_PROJECT_HOME') + '/inputfiles/spiral_8Hz_airbus_3h.txt'
# data = pd.read_csv(filename, sep=' ', names=["t", "x", "y", "z"], header=None)
data = np.loadtxt(filename)
t, x, y, z = data[:,0], data[:,1], data[:,2], data[:,3]

cadence  = 25.  # [s]                                                                                                                                                                             
quarter  = 0                                                                                                                                                                                           
day = 86400.                                                                                                                                                                                            
time_points = int(t[-1] / cadence)
timeStart = round(90. * quarter * day)                                                                                                                                                                   
timeEnd   = round(timeStart + time_points * cadence)                                                                                                                                                    
time = np.arange(timeStart, timeEnd, cadence)

# Find points at cadence
dex = [ut.findNearestIndex(t, time[i]) for i in range(len(time))]
