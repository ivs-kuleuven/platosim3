# %% [markdown]
# # 7. Introduction to the PLATOnium toolkit - Under construction!
#
# In this tutotial we show how easily setup a simulations that involves simulations of the same stellar sample distributed over multiple N-CAMs. We dedicate an tutorial
#
# The 24 telescopes are arranged in 4 groups of 6 telescopes:
#
# - Assuming no alignment errors, all 6 cameras of each group have exactly the same Field-Of-View (FOV)
# - The Lines-Of-Sight (LOS) of the 4 groups are offset by an angle of 9.2° from the PayLoad Module (PLM) +Z axis

# %% [markdown]
# ### Setup notebook

# %%
# Alow changes to the PlatoSim code outside this notebook
# %load_ext autoreload
# %autoreload 2

# Configure figure in notebook
# %matplotlib notebook

# %% [markdown]
# ### Imports

# %%
import os
import h5py
import yaml
import pyaml
import numpy as np
import matplotlib.pyplot as plt
from yaml.loader import SafeLoader

# PlatoSim
from platosim.utilities    import getFunctions
from platosim.simulation   import Simulation
from platosim.simfile      import SimFile
from platosim.matplotlibrc import setup
setup()

# %% [markdown]
# ---
# ## 7.1 - What is PLATOnium?
# ---

# %% [markdown]
# The functions of the `LightCurve` class can be used to **retrieve and analyze the photometric data** of your simulation:

# %%
from platosim.lightcurve import LightCurve
getFunctions(LightCurve)
# Out:
# +---------------------------------+
# |       LightCurve functions      |
# +---------------------------------+
# |             __del__             |
# |             __init__            |
# |        axes_mask_updates        |
# |        axes_quarter_marks       |
# |            bad_files            |
# |               bin               |
# |               cen               |
# |               clip              |
# |         correct_and_save        |
# |           correct_cols          |
# |               data              |
# |             detrend             |
# |              files              |
# |               flux              |
# |             flux_med            |
# |              getMAD             |
# |              getNSR             |
# |              getRMS             |
# |              merge              |
# |          merge_cameras          |
# |               obs               |
# |               plot              |
# |          plot_centroid          |
# ...

# %% [markdown]
# ### Functions that are apart of the Poetry install

# %% [markdown]
# The functions of the `utilities` script are **help functions** used by PlatoSim:

# %%
ut.getFunctions(ut)
# Out:
# +------------------------------+
# | platosim.utilities functions |
# +------------------------------+
# |         compilation          |
# |    convertMagnitudeRange     |
# |     convertQuarterRange      |
# |          errorcode           |
# |       findNearestIndex       |
# |          gaiaQuery           |
# |         getFunctions         |
# |    getPhotonNoiseLimitNSR    |
# |          imageNorm           |
# |     make_axes_locatable      |
# |   medianAbsoluteDeviation    |
# |        median_filter         |
# |             njit             |
# |          normalize           |
# |    passbandConversionV2P     |
# |         pdAddColumn          |
# |        rootMeanSquare        |
# |         stellarFlux          |
# |           ticQuery           |
# |           tqdmBar            |
# +------------------------------+

# %% [markdown]
# The functions of the `plot` utility are **graphical (Matplotlib) tools** used by PlatoSim:

# %%
import platosim.plot as pt 
ut.getFunctions(pt)
# Out:
# +--------------------------------+
# |    platosim.plot functions     |
# +--------------------------------+
# |          axes_minmax           |
# |       discretizeColorbar       |
# |   drawCCDsInCameraFocalPlane   |
# |      drawCCDsInFocalPlane      |
# |     drawCCDsInSkyMollweide     |
# |     drawPixelInFocalPlane      |
# |    drawStarInCCDfocalPlane     |
# |      drawStarInFocalPlane      |
# |      drawStarsInSkyAitoff      |
# |    drawStarsInSkyMollweide     |
# |    drawSubfieldInFocalPlane    |
# |      make_axes_locatable       |
# |       make_interp_spline       |
# |         median_filter          |
# |      moveColorbarExponent      |
# |       plotNSRvsMagnitude       |
# |            plotPSD             |
# |         plotPhotometry         |
# |          plotPlatoFOV          |
# | plotStellarSampleDistributions |
# |     plotSubfieldAnimation      |
# |        plotTeffvsRadius        |
# |     plotYawPitchRollJitter     |
# |      plotYawPitchRollPSD       |
# ...
